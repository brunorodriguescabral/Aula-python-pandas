# %% [markdown]
# <a href="https://colab.research.google.com/github/brunorodriguescabral/Aula-python-pandas/blob/main/Aula_python_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

combustiveis_df = pd.read_excel("ca-2021-02.xlsx")

# %%
display(combustiveis_df)

# %%
display(combustiveis_df.head(5))

# %%
display(combustiveis_df.describe())

# %%
display(combustiveis_df["Municipio"].head(6))

# %%
display(combustiveis_df.shape)

# %%
ca_df = combustiveis_df[["Revenda","Municipio", "Produto", "Valor de Venda"]]
display(ca_df.head(7))
# Out:
#                           Revenda        Municipio             Produto  \
# 0            POSTO ARAPIRACA LTDA        ARAPIRACA            GASOLINA
# 1            POSTO ARAPIRACA LTDA        ARAPIRACA              ETANOL
# 2            POSTO ARAPIRACA LTDA        ARAPIRACA              DIESEL
# 3            POSTO ARAPIRACA LTDA        ARAPIRACA  GASOLINA ADITIVADA
# 4            POSTO ARAPIRACA LTDA        ARAPIRACA          DIESEL S10
# 5  AUTO POSTO FREITAS & MAIA LTDA  DELMIRO GOUVEIA            GASOLINA
# 6  AUTO POSTO FREITAS & MAIA LTDA  DELMIRO GOUVEIA              ETANOL
#
#    Valor de Venda
# 0           6.799
# 1           5.299
# 2           5.549
# 3           6.899
# 4           5.649
# 5           7.198
# 6           5.982

# %%
display(ca_df.loc[158:162])
# Out:
#                        Revenda Municipio             Produto  Valor de Venda
# 158  FERREIRA COMBUSTIVES LTDA  SALVADOR            GASOLINA            6.69
# 159  FERREIRA COMBUSTIVES LTDA  SALVADOR              ETANOL            5.49
# 160  FERREIRA COMBUSTIVES LTDA  SALVADOR  GASOLINA ADITIVADA            6.99
# 161  FERREIRA COMBUSTIVES LTDA  SALVADOR          DIESEL S10            5.49
# 162  FERREIRA COMBUSTIVES LTDA  SALVADOR                 GNV            3.79

# %%
gas = ca_df.loc[ca_df["Produto"] == "GASOLINA"]
display(gas)
# Out:
#                                                   Revenda  \
# 0                                    POSTO ARAPIRACA LTDA
# 5                          AUTO POSTO FREITAS & MAIA LTDA
# 10                               AUTO POSTO DA PEDRA LTDA
# 14                  COMERCIO DE COMBUSTIVEIS NENZITA LTDA
# 19                         MARCOS ANTONIO DA SILVA CABRAL
# ...                                                   ...
# 168392                           AUTO POSTO KM BAURU LTDA
# 168394      COOPERCITRUS COOPERATIVA DE PRODUTORES RURAIS
# 168399  VICMAR COMERCIO DE COMBUSTIVEIS E LUBRIFICANTE...
# 168403         COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405                  ABC DISTRIBUICAO DE PETROLEO LTDA
#
#                     Municipio   Produto  Valor de Venda
# 0                   ARAPIRACA  GASOLINA           6.799
# 5             DELMIRO GOUVEIA  GASOLINA           7.198
# 10            DELMIRO GOUVEIA  GASOLINA           7.197
# ...

# %%
value = ca_df.loc[ca_df["Valor de Venda"] <= 6].loc[ca_df["Produto"] == "GASOLINA"]
display(value)
# Out:
#                                          Revenda           Municipio  \
# 1217                       AUTO POSTO G.E.M.LTDA             ATIBAIA
# 1474                 AUTO POSTO NOVA POA II LTDA                 POA
# 1590                   AUTO POSTO BARCELONA LTDA  SAO CAETANO DO SUL
# 1689         AUTOMOTO - AUTOMOVEIS DO AMAPA LTDA              MACAPA
# 2559              POSTO UNIVERSITARIO SOTTA LTDA              ARARAS
# ...                                          ...                 ...
# 168319  POSTO NOSSA SENHORA DE FATIMA BAURU LTDA               BAURU
# 168322                          POSTO ICCAR LTDA               BAURU
# 168325             AUTO POSTO JARDIM ITALIA LTDA        ITAPETININGA
# 168352     CENTRO AUTOMOTIVO PRIME DE BAURU LTDA               BAURU
# 168384                   AUTO POSTO RAIDEN LTDA.               BAURU
#
#          Produto  Valor de Venda
# 1217    GASOLINA           5.297
# 1474    GASOLINA           5.899
# 1590    GASOLINA           5.999
# ...

# %%
display(ca_df["Valor de Venda"].max())
# Out:
# 8.99

# %%
#Preço do etanol mais barato em indaiatuba

etanol_indaiatuba_df = ca_df.loc[(ca_df['Produto'] == 'ETANOL') & (ca_df['Municipio'] == 'INDAIATUBA')]
etanol_indaiatuba_df.sort_values(by='Valor de Venda', inplace=True)
display(etanol_indaiatuba_df)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                         Revenda   Municipio Produto  \
# 160592             AUTO POSTO NAMORADA II LTDA.  INDAIATUBA  ETANOL
# 140194  CENTRO AUTOMOTIVO RIVIERA TROPICAL LTDA  INDAIATUBA  ETANOL
# 140661      M.LI COMERCIO DE COMBUSTIVEIS LTDA.  INDAIATUBA  ETANOL
# 159497      M.LI COMERCIO DE COMBUSTIVEIS LTDA.  INDAIATUBA  ETANOL
# 141167      AUTO POSTO ESPLANADA DE INDAIA LTDA  INDAIATUBA  ETANOL
# ...                                         ...         ...     ...
# 51129          AUTO POSTO CIDADE DO SOL II LTDA  INDAIATUBA  ETANOL
# 51138              AUTO POSTO NAMORADA II LTDA.  INDAIATUBA  ETANOL
# ...

# %%
#Etanol mais barato de uma cidade usando input

cidade = input("Digite a cidade: ").upper()
etanolprice = ca_df.loc[(ca_df["Produto"] == "ETANOL") & (ca_df["Municipio"] == cidade)]
etanolprice.sort_values(by="Valor de Venda", inplace=True)
display(etanolprice)
# Out:
# Digite a cidade: santos
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                                   Revenda Municipio Produto  \
# 151750  AUTO POSTO E CENTRO DE CONVENIENCIA GLICERIO S...    SANTOS  ETANOL
# 151743                            AUTO POSTO ESPUMAS LTDA    SANTOS  ETANOL
# 139148             COMERCIO DE COMBUSTIVEIS GENESIS LTDA.    SANTOS  ETANOL
# 139178  AUTO POSTO E CENTRO DE CONVENIENCIA GLICERIO S...    SANTOS  ETANOL
# 155749                           AUTO POSTO REVERTON LTDA    SANTOS  ETANOL
# ...                                                   ...       ...     ...
# 49216   CLEAN CAR SUPER LAVAGEM AUTOMÁTICA E COMERCIO ...    SANTOS  ETANOL
# ...

# %%
# Qual a média de preço de gasolina e aditivada do bairro mooca

display(combustiveis_df.loc[(combustiveis_df["Bairro"] == "MOOCA") & 
                            (combustiveis_df["Municipio"] == "SAO PAULO") & 
                            (combustiveis_df["Produto"].isin(["GASOLINA", "GASOLINA ADITIVADA"])), 
                            ['Valor de Venda']].mean())
# Out:
# Valor de Venda    6.575596
# dtype: float64

# %%
# Como mostrar media com valor de venda POR COMBUSTIVEL Brasil todo

media = ca_df[["Produto", "Valor de Venda"]].groupby(by="Produto").mean().round(2)
display(media)
# Out:
#                     Valor de Venda
# Produto
# DIESEL                        5.38
# DIESEL S10                    5.45
# ETANOL                        5.46
# GASOLINA                      6.71
# GASOLINA ADITIVADA            6.86
# GNV                           4.39

# %%
#Quero adicionar uma coluna de valor booleano no combustiveis_df 
# chamada "Ativo"  que, por padrão, vai ser True para 
# TODAS as linhas

combustiveis_df["Ativo"] = True
print(combustiveis_df.info())
display(combustiveis_df.head())

# %%
# Exportar tabela para excel

etanol_indaiatuba_df.to_excel("Etanol_indaiatuba.xlsx", sheet_name="Tabela de Etanol")
